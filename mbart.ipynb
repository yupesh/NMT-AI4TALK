# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install sentencepiece
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 7.6 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 8.4 MB/s
# ...

# %%
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 880 kB 7.6 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=ac6aefa5d95f23dfefb46ec0403005d7e69a6a1c9b4aaa33aca662fa8815468e
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# ...

# %%
#import sys

# %%
# !mosestokenizer
# Out:
# /bin/bash: mosestokenizer: command not found

# %%
import os
import nltk

# %%
! echo $PYTHONPATH
# Out:
# /env/python

# %%
#sys.path.append('/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/')

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/
# Out:
# /content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main

# %%
# !git clone https://github.com/NVIDIA/apex
# !cd apex
# !pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./

# %%
# !git clone https://github.com/pytorch/fairseq
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 33405, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 33405 (delta 0), reused 0 (delta 0), pack-reused 33404
# Receiving objects: 100% (33405/33405), 23.31 MiB | 8.40 MiB/s, done.
# Resolving deltas: 100% (24404/24404), done.
# Checking out files: 100% (1348/1348), done.

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/fairseq/
# Out:
# /content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/fairseq

# %%
# !python -m pip install --editable .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/Colab%20Notebooks/huawei-nlp/final%20project/low_resource_mt-main/fairseq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 241 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 123 kB 91.7 MB/s
# ...
#      |████████████████████████████████| 118 kB 97.6 MB/s
# ...
#      |████████████████████████████████| 112 kB 89.0 MB/s
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141231 sha256=670dbd9ccadf6ee2fe1b065f159df76851eb7d927b7e744ed06c92fe6a97c076
#   Stored in directory: /root/.cache/pip/wheels/c8/d0/ab/d43c02eaddc5b9004db86950802442ad9a26f279c619e28da0
# Successfully built antlr4-python3-runtime
# ...
#   Running setup.py develop for fairseq
# ...

# %%
os.environ['PYTHONPATH'] += ":/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/fairseq/"

! echo $PYTHONPATH
# Out:
# /env/python:/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/fairseq/

# %%
! echo $PYTHONPATH
# Out:
# /env/python:/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/fairseq/

# %%
! echo $PATH
# Out:
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin

# %%
#os.environ['PATH'] += ":/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/"

# %%
! echo $PATH
# Out:
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/fairseq/:/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/fairseq'

# %%
# %cd ../mbart
# Out:
# /content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/mbart

# %%
# !bash ./train_language.sh evenki evn ../../aug_evenki

# %%
# !bash ./train_language.sh evenki evn ../datasets/evenki

# %%
# !fairseq-generate postprocessed_evenki/evn-ru --gen-subset test --path checkpoint_evenki/checkpoint_best.pt --task translation_from_pretrained_bart --batch-size 32 --bpe 'sentencepiece' --sentencepiece-model ../../afrobart/mbart.cc25.v2/sentence.bpe.model --sacrebleu --remove-bpe 'sentencepiece' -s evn_XX -t ru_XX --langs ar_AR,cs_CZ,de_DE,en_XX,es_XX,et_EE,fi_FI,fr_XX,gu_IN,hi_IN,it_IT,ja_XX,kk_KZ,ko_KR,lt_LT,lv_LV,my_MM,ne_NP,nl_XX,ro_RO,ru_RU,si_LK,tr_TR,vi_VN,zh_CN > generation.log

# %%
# !cat generation.log | grep -P "^H" |sort -V |cut -f 3- | sed 's/\[ro_RO\]//g' |sacremoses detokenize > en_ro.hyp
# !cat generation.log | grep -P "^T" |sort -V |cut -f 2- | sed 's/\[ro_RO\]//g' |sacremoses detokenize > en_ro.ref
# !sacrebleu -tok 'none' -s 'none' en_ro.ref < en_ro.hyp
# Out:
# {
#  "name": "BLEU",
#  "score": 43.2,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:none|smooth:none|version:2.3.1",
#  "verbose_score": "63.9/47.3/38.7/34.6 (BP = 0.963 ratio = 0.964 hyp_len = 2121 ref_len = 2201)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "none",
#  "smooth": "none",
#  "version": "2.3.1"
# }

# %%
# !fairseq-generate postprocessed_evenki/evn-ru --gen-subset test --path checkpoint_evenki/checkpoint_best.pt --task translation_from_pretrained_bart --batch-size 32 --bpe 'sentencepiece' --sentencepiece-model ../../afrobart/mbart.cc25.v2/sentence.bpe.model --sacrebleu --remove-bpe 'sentencepiece' -s evn_XX -t ru_XX --langs ar_AR,cs_CZ,de_DE,en_XX,es_XX,et_EE,fi_FI,fr_XX,gu_IN,hi_IN,it_IT,ja_XX,kk_KZ,ko_KR,lt_LT,lv_LV,my_MM,ne_NP,nl_XX,ro_RO,ru_RU,si_LK,tr_TR,vi_VN,zh_CN > generation1.log

# %%
# !fairseq-generate postprocessed_evenki/evn-ru --gen-subset test --path checkpoint_evenki/checkpoint_best.pt --task translation_from_pretrained_bart --batch-size 32 --bpe 'sentencepiece' --sentencepiece-model ../../afrobart/mbart.cc25.v2/sentence.bpe.model --sacrebleu --remove-bpe 'sentencepiece' -s evn_XX -t ru_XX --langs ar_AR,cs_CZ,de_DE,en_XX,es_XX,et_EE,fi_FI,fr_XX,gu_IN,hi_IN,it_IT,ja_XX,kk_KZ,ko_KR,lt_LT,lv_LV,my_MM,ne_NP,nl_XX,ro_RO,ru_RU,si_LK,tr_TR,vi_VN,zh_CN > generation2.log

# %%
# !cat generation2.log | grep -P "^H" |sort -V |cut -f 3- | sed 's/\[ro_RO\]//g' |sacremoses detokenize > ev2_ru.hyp
# !cat generation2.log | grep -P "^T" |sort -V |cut -f 2- | sed 's/\[ro_RO\]//g' |sacremoses detokenize > ev2_ru.ref
# !sacrebleu -tok 'none' -s 'none' ev2_ru.ref < ev2_ru.hyp
# Out:
# {
#  "name": "BLEU",
#  "score": 0.0,
#  "signature": "nrefs:1|case:mixed|eff:no|tok:none|smooth:none|version:2.3.1",
#  "verbose_score": "0.4/0.0/0.0/0.0 (BP = 1.000 ratio = 5.210 hyp_len = 2235 ref_len = 429)",
#  "nrefs": "1",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "none",
#  "smooth": "none",
#  "version": "2.3.1"
# }

# %%
os.environ['PYTHONPATH'] += ":/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main/"

# %%
import sys

# %%
sys.path.append("/content/drive/MyDrive/Colab Notebooks/huawei-nlp/final project/low_resource_mt-main")

# %%
with open("en_ro.ref") as ref:
  refs = [line for line in ref]
with open("en_ro.hyp") as hyp:
  hyps = [line for line in hyp]

# %%
from compute_bleu import compute_4_bleu
result = compute_4_bleu(refs, hyps)
# Out:
# /usr/local/lib/python3.8/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.8/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# BLEU1 = 48.0/100
# BLEU2 = 0.0/100
# BLEU3 = 0.0/100
# BLEU4 = 0.0/100
# /usr/local/lib/python3.8/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# ...

# %%
BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis)

# %%
# !pip install colab-xterm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 115 kB 32.0 MB/s
# ...

# %%
# %load_ext colabxterm

# %%
# %xterm
